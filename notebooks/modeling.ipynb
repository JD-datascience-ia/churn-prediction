# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, precision_recall_curve, classification_report
from sklearn.model_selection import cross_validate, GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
X_train = pd.read_csv("../data/X_train.csv")
X_test = pd.read_csv("../data/X_test.csv")
y_train = pd.read_csv("../data/y_train.csv").squeeze()
y_test = pd.read_csv("../data/y_test.csv").squeeze()

# %% [markdown]
# J'importe mon preprecessing précédent, j'ai aussi appris que .squeeze permet de garder la series, très utile.

# %%
pipeline = make_pipeline(
    StandardScaler(),
    LogisticRegression(max_iter=3000)
)

# %%
cv_results = cross_validate(
    pipeline,
    X_train,
    y_train,
    cv=5,
    scoring=["accuracy", "precision", "recall", "f1", "roc_auc"]
)

# %%
res = pd.DataFrame(cv_results)
res
# Out:
#    fit_time  score_time  test_accuracy  test_precision  test_recall   test_f1  \
# 0  0.022076    0.012454       0.786667        0.612167     0.538462  0.572954
# 1  0.014060    0.012059       0.820444        0.704641     0.558528  0.623134
# 2  0.014858    0.011583       0.805333        0.662602     0.545151  0.598165
# 3  0.015355    0.012165       0.791111        0.629032     0.521739  0.570384
# 4  0.014294    0.013650       0.808889        0.660305     0.578595  0.616756
#
#    test_roc_auc
# 0      0.836600
# 1      0.874076
# 2      0.840793
# 3      0.819301
# 4      0.859119

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression(max_iter=3000))])

# %%
y_pred = pipeline.predict(X_test)

# %%
print("Recall :", recall_score(y_test, y_pred))
# Out:
# Recall : 0.5748663101604278

# %%
grid = GridSearchCV(
    pipeline,
    param_grid={
        "logisticregression__C": [0.01, 0.1, 1, 10],
        "logisticregression__solver": ["lbfgs", "liblinear"],
        "logisticregression__class_weight": [None, "balanced"]
    },
    cv=5,
    scoring="f1"
)

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('logisticregression',
#                                         LogisticRegression(max_iter=3000))]),
#              param_grid={'logisticregression__C': [0.01, 0.1, 1, 10],
#                          'logisticregression__class_weight': [None, 'balanced'],
#                          'logisticregression__solver': ['lbfgs', 'liblinear']},
#              scoring='f1')

# %%
print("Best params :", grid.best_params_)
print("Best score :", grid.best_score_)
# Out:
# Best params : {'logisticregression__C': 1, 'logisticregression__class_weight': 'balanced', 'logisticregression__solver': 'liblinear'}
# Best score : 0.6325749591946266

# %%
best_model = grid.best_estimator_

y_pred = best_model.predict(X_test)
y_proba = best_model.predict_proba(X_test)[:, 1]

# %%
y_pred, y_proba
# Out:
# (array([0, 1, 0, ..., 0, 0, 0], shape=(1407,)),
#  array([0.04946132, 0.7879942 , 0.01413646, ..., 0.27442132, 0.06512004,
#         0.01357934], shape=(1407,)))

# %%
results = pd.DataFrame({
    "y_true": y_test,
    "y_pred": y_pred,
    "proba_churn": y_proba
})

results.head(10)
# Out:
#    y_true  y_pred  proba_churn
# 0       0       0     0.049461
# 1       0       1     0.787994
# 2       0       0     0.014136
# 3       1       0     0.399566
# 4       0       0     0.228618
# 5       1       1     0.721096
# 6       0       0     0.073560
# 7       0       0     0.347420
# 8       1       1     0.849701
# 9       0       0     0.046010

# %%
print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision :", precision_score(y_test, y_pred))
print("Recall :", recall_score(y_test, y_pred))
print("F1-score :", f1_score(y_test, y_pred))
# Out:
# Accuracy : 0.7263681592039801
# Precision : 0.49093904448105435
# Recall : 0.7967914438502673
# F1-score : 0.6075433231396534

# %%
metrics = {
    "accuracy": accuracy_score(y_test, y_pred),
    "precision": precision_score(y_test, y_pred),
    "recall": recall_score(y_test, y_pred),
    "f1": f1_score(y_test, y_pred)
}

plt.figure(figsize=(8,5))
plt.bar(metrics.keys(), metrics.values())
plt.ylim(0, 1)
plt.ylabel("Score")
plt.title("Performance du modèle")
plt.show()

# %% [markdown]
# # Grâce a ce modèle, j'identifie presque 80% des clients qui vont churn, mais j'ai une précision plutôt faible, d'environ 50%, je vais donc aussi signaler des clients qui ne feront pas de churn.
# # Dans notre cas j'estime qu'il est important de detecté un maximum de client qui peuvent potentiellement churn, quitte à cibler aussi ceux qui ne partirons pas.
# # Je vais explorer d'autre modeles, pour vois si je peux avoir une meilleur precision et garder ou amélioré mon recall.

# %%
pipeline2 = make_pipeline(
    StandardScaler(),
    RandomForestClassifier()
)

# %%
cv_results2 = cross_validate(
    pipeline2,
    X_train,
    y_train,
    cv=5,
    scoring=["accuracy", "precision", "recall", "f1", "roc_auc"]
)

# %%
res2 = pd.DataFrame(cv_results)
res2
# Out:
#    fit_time  score_time  test_accuracy  test_precision  test_recall   test_f1  \
# 0  0.338754    0.040378       0.785778        0.620833     0.498328  0.552876
# 1  0.298980    0.040234       0.799111        0.662222     0.498328  0.568702
# 2  0.333247    0.039119       0.783111        0.614108     0.494983  0.548148
# 3  0.294697    0.038857       0.766222        0.579646     0.438127  0.499048
# 4  0.323918    0.038754       0.785778        0.618852     0.505017  0.556169
#
#    test_roc_auc
# 0      0.821777
# 1      0.835094
# 2      0.828290
# 3      0.805022
# 4      0.837720

# %%
pipeline2.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
y_pred2 = pipeline2.predict(X_test)

# %%
print("Recall :", recall_score(y_test, y_pred2))
# Out:
# Recall : 0.48663101604278075

# %%
rf = RandomForestClassifier(random_state=42)

param_grid2 = {
    "n_estimators": [100, 200, 300],
    "max_depth": [5, 10, 20],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [2, 4, 6],
    "max_features": ["sqrt", 0.5],
    "class_weight": [None, "balanced"]
}

grid2 = GridSearchCV(
    rf,
    param_grid=param_grid2,
    cv=5,
    scoring="recall",
    n_jobs=-1
)

# %%
grid2.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'class_weight': [None, 'balanced'],
#                          'max_depth': [5, 10, 20],
#                          'max_features': ['sqrt', 0.5],
#                          'min_samples_leaf': [2, 4, 6],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300]},
#              scoring='recall')

# %%
print("Best params :", grid2.best_params_)
print("Best score :", grid2.best_score_)
# Out:
# Best params : {'class_weight': 'balanced', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 200}
# Best score : 0.8080267558528428

# %%
best_model2 = grid2.best_estimator_

y_pred2 = best_model2.predict(X_test)
y_proba2 = best_model2.predict_proba(X_test)[:, 1]

# %%
print("Accuracy :", accuracy_score(y_test, y_pred2))
print("Precision :", precision_score(y_test, y_pred2))
print("Recall :", recall_score(y_test, y_pred2))
print("F1-score :", f1_score(y_test, y_pred2))
# Out:
# Accuracy : 0.7249466950959488
# Precision : 0.4894308943089431
# Recall : 0.8048128342245989
# F1-score : 0.6086956521739131

# %%
metrics = {
    "accuracy": accuracy_score(y_test, y_pred2),
    "precision": precision_score(y_test, y_pred2),
    "recall": recall_score(y_test, y_pred2),
    "f1": f1_score(y_test, y_pred2)
}

plt.figure(figsize=(8,5))
plt.bar(metrics.keys(), metrics.values())
plt.ylim(0, 1)
plt.ylabel("Score")
plt.title("Performance du modèle")
plt.show()

# %% [markdown]
# # Après un essai avec un modèle random forest, je me rend compte que les résultats sont similaire, voir identiques a quelques chose près.
# # Je suppose donc que je suis limité par la quantité d'information du data set.
# # Par experiences lors de mes essais, le xgboost fonctionnais bien pour les classes déséquilibrées, je vais donc l'essayer en tant que dernier modèle.

# %%
pipeline3 = make_pipeline(
    StandardScaler(),
    XGBClassifier()
)

# %%
cv_results3 = cross_validate(
    pipeline3,
    X_train,
    y_train,
    cv=5,
    scoring=["accuracy", "precision", "recall", "f1", "roc_auc"]
)

# %%
res3 = pd.DataFrame(cv_results)
res3
# Out:
#    fit_time  score_time  test_accuracy  test_precision  test_recall   test_f1  \
# 0  0.338754    0.040378       0.785778        0.620833     0.498328  0.552876
# 1  0.298980    0.040234       0.799111        0.662222     0.498328  0.568702
# 2  0.333247    0.039119       0.783111        0.614108     0.494983  0.548148
# 3  0.294697    0.038857       0.766222        0.579646     0.438127  0.499048
# 4  0.323918    0.038754       0.785778        0.618852     0.505017  0.556169
#
#    test_roc_auc
# 0      0.821777
# 1      0.835094
# 2      0.828290
# 3      0.805022
# 4      0.837720

# %%
pipeline3.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_bytree=None, device=None,
#                                early_stopping_rounds=None,
#                                enable_categorical=False, eval_metric=None,
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
# ...

# %%
y_pred3 = pipeline3.predict(X_test)

# %%
print("Recall :", recall_score(y_test, y_pred3))
# Out:
# Recall : 0.5481283422459893

# %%
xgb = XGBClassifier(
    objective="binary:logistic",
    eval_metric="logloss",
    random_state=42
)

param_grid3 = {
    "n_estimators": [100, 200],
    "learning_rate": [0.05, 0.1],
    "max_depth": [3, 5],
    "min_child_weight": [1, 3],
    "gamma": [0, 0.2],
    "subsample": [0.8, 1.0],
    "colsample_bytree": [0.8, 1.0],
    "scale_pos_weight": [1, 3]
}

grid3 = GridSearchCV(
    estimator=xgb,
    param_grid=param_grid3,
    cv=5,
    scoring="recall",
    n_jobs=-1
)

# %%
grid3.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False,
#                                      eval_metric='logloss', feature_types=None,
#                                      feature_weights=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraint...
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
# ...

# %%
print("Best params :", grid3.best_params_)
print("Best score :", grid3.best_score_)
# Out:
# Best params : {'colsample_bytree': 1.0, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'scale_pos_weight': 3, 'subsample': 1.0}
# Best score : 0.8267558528428094

# %%
best_model3 = grid3.best_estimator_

y_pred3 = best_model2.predict(X_test)
y_proba3 = best_model2.predict_proba(X_test)[:, 1]

# %%
print("Accuracy :", accuracy_score(y_test, y_pred3))
print("Precision :", precision_score(y_test, y_pred3))
print("Recall :", recall_score(y_test, y_pred3))
print("F1-score :", f1_score(y_test, y_pred3))
# Out:
# Accuracy : 0.7249466950959488
# Precision : 0.4894308943089431
# Recall : 0.8048128342245989
# F1-score : 0.6086956521739131

# %%
metrics3 = {
    "accuracy": accuracy_score(y_test, y_pred3),
    "precision": precision_score(y_test, y_pred3),
    "recall": recall_score(y_test, y_pred3),
    "f1": f1_score(y_test, y_pred3)
}

plt.figure(figsize=(8,5))
plt.bar(metrics.keys(), metrics3.values())
plt.ylim(0, 1)
plt.ylabel("Score")
plt.title("Performance du modèle")
plt.show()

# %% [markdown]
# # Je remarque que le xgboost n'est pas magique, mes resultats sont quasiment identiques. Même si je finetune mes grids, je suppose que les changements seront minimes et peu intéréssant.
# # Etant limité par le dataset, je ne peux pas prendre plus de données, je vais devoir travailler sur du feature engineering et leur sélection, c'est la piste la plus probable pour amélioré mes résultats, je le rapelle l'objectif étant d'identifié un maximum de clients qui vont potentiellement churn, avec la meilleur précision possible.
